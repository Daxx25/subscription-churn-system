# %%
import pandas as pd
import numpy as np

df = pd.read_csv("F:/subscription-churn-system/dataset/cleaned_telco_churn.csv")
np.random.seed(42)

df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges        Churn
# count    7043.000000  7043.000000     7043.000000   7032.000000  7043.000000
# mean        0.162147    32.371149       64.761692   2283.300441     0.265370
# std         0.368612    24.559481       30.090047   2266.771362     0.441561
# min         0.000000     0.000000       18.250000     18.800000     0.000000
# 25%         0.000000     9.000000       35.500000    401.450000     0.000000
# 50%         0.000000    29.000000       70.350000   1397.475000     0.000000
# 75%         0.000000    55.000000       89.850000   3794.737500     1.000000
# max         1.000000    72.000000      118.750000   8684.800000     1.000000

# %%
#Average Weekly Usage
df["avg_weekly_sessions"] = np.clip(
    np.random.normal(loc=5 + df["tenure"]/12, scale=2),
    0,
    None
)

# %%
#Usage Trend (Drop-off is deadly)
df["usage_trend_30d"] = np.random.normal(
    loc=np.where(df["Churn"] == 1, -0.3, 0.1),
    scale=0.2
)
#Negative trend → disengaging user

# %%
#Support Tickets
df["support_tickets_90d"] = np.random.poisson(
    lam=np.where(df["Churn"] == 1, 2, 0.5)
)

# %%
#Payment Failures
df["payment_failures"] = np.random.binomial(
    n=3,
    p=np.where(df["Churn"] == 1, 0.4, 0.1)
)

# %%
#Engagement Score (Composite Feature)
df["engagement_score"] = (
    0.4 * df["avg_weekly_sessions"] +
    0.3 * (1 + df["usage_trend_30d"]) +
    0.3 * (1 / (1 + df["support_tickets_90d"]))
)

# %%
#Drop original churn label after using it only to simulate behavior.
df["churn_30d"] = df["Churn"]
df = df.drop(columns=["Churn"])

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... PaperlessBilling  \
# 0  No phone service             DSL             No  ...              Yes
# 1                No             DSL            Yes  ...               No
# 2                No             DSL            Yes  ...              Yes
# 3  No phone service             DSL            Yes  ...               No
# 4                No     Fiber optic             No  ...              Yes
#
#                PaymentMethod MonthlyCharges TotalCharges avg_weekly_sessions  \
# 0           Electronic check          29.85        29.85            6.076762
# 1               Mailed check          56.95      1889.50            7.556805
# 2               Mailed check          53.85       108.15            6.462044
# 3  Bank transfer (automatic)          42.30      1840.75           11.796060
# 4           Electronic check          70.70       151.65            4.698360
#
#   usage_trend_30d support_tickets_90d payment_failures  engagement_score  \
# 0       -0.204467                   0                0          2.969365
# 1        0.259595                   1                0          3.550600
# 2       -0.411022                   1                1          2.911511
# 3        0.102434                   0                1          5.349154
# 4       -0.318575                   1                1          2.233771
#
#    churn_30d
# 0          0
# 1          0
# 2          1
# 3          0
# 4          1
#
# [5 rows x 26 columns]

# %%
#Encode Categorical Variables
categorical_cols = df.select_dtypes(include="object").columns
df_encoded = pd.get_dummies(df, columns=categorical_cols, drop_first=True)
df_encoded.head()
# Out:
#    SeniorCitizen  tenure  MonthlyCharges  TotalCharges  avg_weekly_sessions  \
# 0              0       1           29.85         29.85             6.076762
# 1              0      34           56.95       1889.50             7.556805
# 2              0       2           53.85        108.15             6.462044
# 3              0      45           42.30       1840.75            11.796060
# 4              0       2           70.70        151.65             4.698360
#
#    usage_trend_30d  support_tickets_90d  payment_failures  engagement_score  \
# 0        -0.204467                    0                 0          2.969365
# 1         0.259595                    1                 0          3.550600
# 2        -0.411022                    1                 1          2.911511
# 3         0.102434                    0                 1          5.349154
# 4        -0.318575                    1                 1          2.233771
#
#    churn_30d  ...  StreamingTV_No internet service  StreamingTV_Yes  \
# 0          0  ...                            False            False
# 1          0  ...                            False            False
# 2          1  ...                            False            False
# 3          0  ...                            False            False
# 4          1  ...                            False            False
#
#    StreamingMovies_No internet service  StreamingMovies_Yes  \
# 0                                False                False
# 1                                False                False
# 2                                False                False
# 3                                False                False
# 4                                False                False
#
#    Contract_One year  Contract_Two year  PaperlessBilling_Yes  \
# 0              False              False                  True
# 1               True              False                 False
# 2              False              False                  True
# 3               True              False                 False
# 4              False              False                  True
#
#    PaymentMethod_Credit card (automatic)  PaymentMethod_Electronic check  \
# 0                                  False                            True
# 1                                  False                           False
# 2                                  False                           False
# 3                                  False                           False
# 4                                  False                            True
#
#    PaymentMethod_Mailed check
# 0                       False
# 1                        True
# 2                        True
# 3                       False
# 4                       False
#
# [5 rows x 7078 columns]

# %%
#Train / Validation Split (Time-Aware)
df_encoded = df_encoded.sort_values("tenure")

split_idx = int(len(df_encoded) * 0.8)
train = df_encoded.iloc[:split_idx]
valid = df_encoded.iloc[split_idx:]

X_train = train.drop("churn_30d", axis=1)
y_train = train["churn_30d"]

X_valid = valid.drop("churn_30d", axis=1)
y_valid = valid["churn_30d"]

# %%
# Save Features
train.to_csv("F:/subscription-churn-system/data/processed/train_features.csv", index=False)
valid.to_csv("F:/subscription-churn-system/data/processed/valid_features.csv", index=False)
